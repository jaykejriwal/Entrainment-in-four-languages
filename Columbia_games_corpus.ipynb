# %%
## First step 
## Download the columbia games corpus to a specific location
## Later, execute the code in sequence 
## This program reads each words file and creates a new words file with additional information about "speaker" and "filename".
## The program reads the .words file from each folder and creates a new words file with the extension .words_with_speaker
## For instance, s01.cards.1.A.words will be processed, and the new file will be created on the same path with s01.cards.1.A.words_with_speaker

#Program to add speaker and filename column in each word file
import os
import sys
import glob
import os.path
import pandas as pd
import re

#Specify the path of the dataset
list_of_files = glob.glob(r'D:\Jay\columbia-games-corpus\dataset\**\*.words',recursive=True) 

for file_name in list_of_files:    
    out_name=file_name+'_with_speaker'
    csv_input = pd.read_csv(file_name,delimiter=' ',header=None)
    csv_input['Speaker'] = file_name[-7]
    csv_input['filename'] = file_name
    csv_input.to_csv(out_name, index=False,header=False,sep=' ')

# %%
#Second step 
## The program reads each words_with_speaker file processed in the first step and combines the text files of both speakers in each session.
## For instance, s01.cards.1.A.words_with_speaker and s01.cards.1.B.words_with_speaker will be read and combined. 
## The output will be saved as s01.objects.1.A.words_with_speaker_txt
## The program also converts each flac file into wav file format
## For instance, s01.cards.1.A.flac will be transformed to s01.objects.1.A.wav

#Program to merge Speaker text files and convert flac files
import os
import fnmatch
import sys
import subprocess

#Specify path of dataset
OLD_BASE = r'D:\Jay\columbia-games-corpus\dataset'

#Create the empty folder where ouput needs to be saved
#Specify path of output folder
NEW_BASE = r'D:\Jay\columbia-games-corpus\data'

#Specify path of ffmpeg for converting audio files
ffp=r"C:\ffmpeg-master-latest-win64-gpl\bin\ffmpeg"

def merge_files(infiles):
    output=os.path.basename(infiles[0][:-9])+'_txt'
    outfiletxt = os.path.join(new_dir, output)
    with open(outfiletxt, 'wb') as fo:
        for infile in infiles:
            with open(infile, 'rb') as fi:
                fo.write(fi.read())

def convert_files(infiles):
    output_channel1=os.path.basename(infiles[0][:-5])+'.wav'
    output_channel2=os.path.basename(infiles[1][:-5])+'.wav'
    outfile1 = os.path.join(new_dir, output_channel1)
    outfile2 = os.path.join(new_dir, output_channel2)
    cmd2wav1 = ffp+' -i ' + infiles[0] + ' ' + outfile1
    cmd2wav2 = ffp+' -i ' + infiles[1] + ' ' + outfile2
    #print(cmd2wav)
    subprocess.call(cmd2wav1, shell=True)
    subprocess.call(cmd2wav2, shell=True)

for (dirpath, dirnames, filenames) in os.walk(OLD_BASE):
    base, tail = os.path.split(dirpath)
    if base != OLD_BASE: continue  # Don't operate on OLD_BASE, only children directories

    # Build infiles list for flac objects
    object_flac = sorted([os.path.join(dirpath, filename) for filename in filenames if fnmatch.fnmatch(filename,"*objects*.flac")])
    # Build infiles list for words objects
    object_text = sorted([os.path.join(dirpath, filename) for filename in filenames if fnmatch.fnmatch(filename,"*objects*.words_with_speaker")])

    # Create output directory
    new_dir =  os.path.join(NEW_BASE, tail)
    os.mkdir(new_dir)  # This will raise an OSError if the directory already exists    

    # Merge
    convert_files(object_flac)
    merge_files(object_text)

# %%
#Third step 
## The program reads each concatenated words_with_speaker_txt file processed in the second step and further processes it in the following way.
## Each word consecutively spoken by a speaker is merged and converted into a turn.
## Similarly, start and end times are adjusted accordingly
## For instance, s01.objects.1.A.words_with_speaker_txt will be read and s01.objects.1.txt will be generated in same folder. 
#Program to extract turns

import os
import sys
import glob
import os.path
import pandas as pd

#Add path for output files saved in second step
list_of_files = glob.glob(r'D:\Jay\columbia-games-corpus\data\**\*.words_wittxt',recursive=True) 

for file_name in list_of_files:    
    out_name=file_name[:-14]+'txt'
    headers= ['start','end','words','Speaker','filename']
    csv_input = pd.read_csv(file_name,delimiter=' ')
    csv_input.columns = headers
    #csv_input
    cgc2=csv_input.sort_values(['start'])    
    cgc3=cgc2[cgc2["words"].str.contains("#")==False]
    cgc3[['start', 'end']] = cgc3[['start', 'end']].astype(str)
    cgc3['obj1_count'] = (cgc3['Speaker'].ne(cgc3['Speaker'].shift())).cumsum()
    df3=cgc3.groupby('obj1_count').agg(lambda x: ' '.join(x))
    df3['start'] = df3['start'].map(lambda x: x.split(" ")[0])
    df3['end'] = df3['end'].map(lambda x: x.split(" ")[-1])
    df3['Speaker'] = df3['Speaker'].map(lambda x: x.split(" ")[-1])
    df3['filename'] = df3['filename'].map(lambda x: x.split(" ")[-1])
    df3['filename'] = df3['filename'].str.replace('words','wav')
    df3['filename'] = df3['filename'].str.replace('dataset','data')
    df3['session']=re.search('(\d\d)',file_name)[0]
    if df3.iloc[-1]['Speaker'] == df3.iloc[0]['Speaker']:
        df4=df3.drop(df3.index[len(df3)-1])
        df4.to_csv(out_name, index=False,header=False,sep='\t')
        del df4
    else:
        df3.to_csv(out_name, index=False,header=False,sep='\t')
    del csv_input,cgc2,cgc3,df3

# %%
#Fourth step 
## Program to delete words_with_speaker_txt file
## The program deletes all the words_with_speaker_txt files generated in second step
## The program allows better readability of the generated output
## After executing the program, Each session folder will have two wav files and one txt file
## For instance, s01.objects.1.A.wav, s01.objects.1.B.wav and s01.objects.1.txt 
#Delete files with unwanted extension
import glob
# Please specify path of the folder 

for f in glob.glob(r'D:\Jay\columbia-games-corpus\data\**\*.words_wittxt',recursive=True):
    os.remove(f)

# %%
#Fifth step 
## Program to extract textual, semantic and auditory embeddings from each turn
## The program reads each text file generated in the third step and extracts text, TRILL vectors and semantic embeddings from each turn
## The program saves embeddings in pkl file format

import pandas as pd
from sentence_transformers import SentenceTransformer, util
from transformers import BertTokenizer, BertModel
import torch
from functools import reduce
import csv
from sklearn.metrics.pairwise import cosine_similarity
import random
import subprocess
import re
import glob
import os,sys
import numpy as np
import soundfile as sf
import wave
import json
import tensorflow as tf1
import tensorflow_hub as hub
# Import TF 2.X and make sure we're running eager.
import tensorflow.compat.v2 as tf
#import tensorflow as tf
from sklearn.metrics.pairwise import cosine_similarity
modulev3=None
modulev3_graph=None
import pickle
tf.enable_v2_behavior()
assert tf.executing_eagerly()

##Function to load TRILL vector model    
def get_TRILLv3_signal(signal,samplerate):
    global modulev3
    if modulev3==None:
        #Specify the path of TRILL vector model
        print('******************\nLoading model ...\n******************')    
        modulev3 = hub.load(r'D:\Jay\columbia-games-corpus\trill_extraction_v2\v3')
    
    
    max_int16 = 2**15
    chunks_cnt=int(signal.shape[0]/(samplerate*10.0))#10 seconds max in chunk
    if chunks_cnt==0:
        chunks=[signal]
    else:
        chunks=np.array_split(signal, chunks_cnt)
    
    trillv3_emb_all=np.empty(shape=(0,512))
    
    for chunk in chunks:
        trillv3 = modulev3(samples=chunk, sample_rate=samplerate)
        trillv3_emb = trillv3['embedding']
        trillv3_emb_all=np.concatenate((trillv3_emb_all, trillv3_emb))

    trillv3_emb_avg = np.mean(trillv3_emb_all, axis=0, keepdims=False)

    return (trillv3_emb_avg.tolist())    

##Function to check if audio files are in proper format 
def check_wav_format(wav_file, start, end):
    wf = wave.open(wav_file)
    nchannels, sampwidth, framerate, nframes, comptype, compname = wf.getparams()
    print(nchannels, sampwidth, framerate, nframes, comptype, compname)
    wav_length = float(nframes) / float(framerate)
    print(wav_length)		
    return(framerate)

##Function to extract TRILL embeddings from specific file name with start and end time as parameters   
def get_TRILLv3_audiofile_from_to(wav_file,start,end):
    print('get_TRILLv3_signal:',wav_file,start,end)
    samplerate=check_wav_format(wav_file, start, end)   
    startsample=int(start*samplerate)
    endsample=int(end*samplerate)
    signal, samplerate = sf.read(wav_file,start=startsample, stop=endsample)
    print(len(signal),samplerate)    

    trill=get_TRILLv3_signal(signal,samplerate)
    return(trill)

##Specify input path from where text files needs to be read
#Specify path for files generated in third step
path = r'D:\Jay\columbia-games-corpus\data'
#Specify path where auditory embeddings needs to be saved
audio_embedding_path = 'D:\\Jay\\columbia-games-corpus\\Pickle\\audio\\'
#Specify path where textual embeddings needs to be saved
text_embedding_path = 'D:\\Jay\\columbia-games-corpus\\Pickle\\text\\'
#Specify path where semantic embeddings needs to be saved
semantic_embedding_path = 'D:\\Jay\\columbia-games-corpus\\Pickle\\semantic\\'
#Initialize transformer model for semantic feature extraction
model = SentenceTransformer("sentence-transformers/msmarco-distilbert-base-v4")


for root, dirs, files in os.walk(path):
    for file in files:
        if file.endswith('.txt'):
            with open(os.path.join(root, file), 'r', encoding="utf8") as f:
                out_audio_embedding= os.path.join(audio_embedding_path, os.path.basename(file))
                out_semantic_embedding= os.path.join(semantic_embedding_path, os.path.basename(file))
                out_text_embedding= os.path.join(text_embedding_path, os.path.basename(file))
                sentenceembeddings=[]
                audioembeddings = []
                sentence_embeddings_tensor = []
                text = f.readlines()
                for line in text:
                    n1=line.split('\t')[0]
                    n2=line.split('\t')[1]
                    sentence=line.split('\t')[2]
                    n3=line.split('\t')[4]
                    n4=os.path.join(root,n3).replace('\n','')
                    x=get_TRILLv3_audiofile_from_to(n4,float(n1),float(n2))
                    sentenceembeddings.append(sentence)
                    audioembeddings.append(x)
                sentence_embeddings_tensor = model.encode(sentenceembeddings, convert_to_tensor=False)
                sentence_embeddings_tensor=sentence_embeddings_tensor.tolist()
                with open(out_audio_embedding+'.pkl', 'wb') as f:
                    pickle.dump(audioembeddings, f)
                with open(out_text_embedding+'.pkl', 'wb') as f:
                    pickle.dump(sentenceembeddings, f)
                with open(out_semantic_embedding+'.pkl', 'wb') as f:
                    pickle.dump(sentence_embeddings_tensor, f)
# Out:
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 2.065 2.2075
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 2280 16000
# ******************
# Loading model ...
# ******************
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 12.199908 22.75
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 168802 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 22.78 23.68
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 14400 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 24.015 24.875
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 13760 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 25.0275 25.9875
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 15360 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 26.45648 27.57648
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 17920 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 42.265 42.436846
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 2749 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 46.548548 59.4625
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 206624 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 59.245 59.694332
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 7189 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 75.656642 83.346642
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 123040 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 83.325 83.5975
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 4360 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 83.346642 83.69
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 5494 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 85.55 86.0475
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 7960 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 86.3075 86.734695
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 6835 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 90.4625 91.040675
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 9250 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 91.025 104.5625
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 216600 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 105.0325 110.3975
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 85840 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 111.124817 111.7725
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 10363 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 112.138918 113.687157
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 24772 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 113.634817 113.824817
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 3040 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 113.687157 113.94571
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 4137 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 113.824817 114.3125
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 7803 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 114.222088 114.577157
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 5681 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 114.3125 118.0125
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 59200 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 117.474482 118.480236
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 16092 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 118.4775 119.0025
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 8400 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 118.786039 119.176039
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 6240 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 119.0025 125.1675
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 98640 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 125.745539 129.37511
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 58073 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 136.165 136.665109
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 8001 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 136.6625 136.947027
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 4552 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 136.665109 137.3875
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 11559 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 141.561301 146.551301
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 79840 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 146.995 156.775
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 156480 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 160.958314 165.175806
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 67479 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 165.245 165.88
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 10160 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 172.995806 173.125
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 2068 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 176.4875 176.845
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 5720 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 177.462802 182.042802
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 73280 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 182.213477 183.605
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 22265 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 185.464492 187.174492
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 27360 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 189.495 189.72
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 3600 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 189.846482 190.175
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 5257 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 198.32 203.876967
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 88911 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 203.7025 203.9325
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 3680 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 204.105 206.3325
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 35640 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 215.2475 215.470539
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 3568 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 215.36 216.085
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 11600 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 215.576838 238.5825
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 368091 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 239.04156 240.72156
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 26880 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 240.671507 241.071507
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 6400 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 240.72156 241.45156
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 11680 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 241.431507 241.737879
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 4902 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 241.45156 242.045
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 9496 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 241.961507 242.497453
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 8575 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 242.85156 242.99156
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 2240 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 242.8875 243.0375
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 2400 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 242.99156 244.075
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 17336 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 244.075 247.74108
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 58657 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 248.5525 249.9325
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 22080 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 250.696905 253.182637
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 39772 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 254.205 258.1775
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 63560 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 258.777981 264.5875
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 92953 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 264.8425 267.1625
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 37120 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 266.8825 267.887981
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 16087 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 268.0025 268.2175
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 3440 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 268.0425 268.27
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 3640 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 268.2175 268.3125
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 1520 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 268.57 269.3175
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 11960 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 269.7075 271.305
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 25560 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 271.1275 271.324269
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 3148 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 271.510132 271.8375
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 5238 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 271.825 272.0975
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 4360 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 271.8375 272.3675
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 8480 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 272.325 272.3775
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 840 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 272.3675 272.675
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 4920 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 272.3775 272.848584
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 7537 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 279.971928 291.3075
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 181370 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 291.435 291.782056
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 5552 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 291.54 292.51
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 15520 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 300.327022 300.653083
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 5217 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 302.795 303.46
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 10640 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 309.420259 322.909
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 215820 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 323.0775 323.56
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 7720 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 324.080005 326.799802
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 43516 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 327.0975 327.675
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 9240 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 327.580005 333.200005
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 89920 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 333.3225 333.545
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 3560 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 333.640005 336.150541
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 40168 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 336.1375 336.3075
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 2720 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 336.150541 336.396432
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 3934 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 336.3075 336.9375
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 10080 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 336.8525 338.967427
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 33838 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 339.362459 340.941505
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 25265 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 341.76 343.220969
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 23375 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 343.2225 347.925
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 75240 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 347.545 347.996818
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 7229 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 347.925 348.05
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 2000 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 347.996818 348.256818
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 4160 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 348.05 348.455223
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 6483 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 348.256818 348.576818
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 5120 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 348.455223 348.975
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 8317 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 348.866818 349.316818
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 7200 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 348.975 349.73
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 12080 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 349.806818 352.133199
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 37222 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 352.0825 352.6275
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 8720 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 352.476818 352.734659
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 4125 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 352.6275 354.1725
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 24720 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 354.06 354.353889
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 4702 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 354.1725 355.5725
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 22400 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 355.76 360.096818
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 69389 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 360.3925 361.250996
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 13735 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 361.106818 361.301475
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 3114 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 361.250996 361.527746
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 4428 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 361.470223 363.086818
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 25866 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 363.1825 364.335
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 18440 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 364.205 364.345
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 2240 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 364.335 364.6275
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 4680 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 364.345 364.649911
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 4878 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 364.6275 365.025
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 6360 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 364.649911 364.795
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 2322 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 365.025 365.27
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 3920 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 365.13 367.306818
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 34829 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 366.9275 367.128092
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 3209 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 367.306818 367.983884
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 10833 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 367.9575 368.430996
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 7575 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 367.983884 368.496818
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 8207 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 368.430996 368.750996
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 5120 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 368.496818 368.896818
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 6400 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 368.750996 368.8575
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 1705 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 368.896818 369.1
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 3251 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 369.175 372.6675
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 55880 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 372.155938 372.505
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 5585 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 372.6675 380.795
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 130040 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 380.5475 380.7825
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 3760 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 380.952741 384.742741
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 60640 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 384.665 384.8825
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 3480 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 384.742741 385.4825
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 11837 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 385.576998 385.843544
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 4265 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 386.272741 391.792741
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 88320 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 391.605 391.7075
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 1640 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 391.792741 392.48
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 10997 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 392.4025 393.385
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 15720 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 393.295 393.462741
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 2683 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 393.385 393.6125
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 3640 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 393.462741 393.9375
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 7597 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 393.6125 393.8225
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 3360 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 393.9375 394.235
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 4760 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 393.963369 394.3425
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 6067 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 394.235 396.215
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 31680 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 396.0575 396.29
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 3720 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 396.215 397.3425
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 18040 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 397.4375 398.4225
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 15760 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 398.365 399.08
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 11440 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 398.747839 400.225714
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 23646 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 400.3375 401.082741
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 11923 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 400.73 401.353917
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 9982 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 401.472741 404.615
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 50277 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 404.39 405.37
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 15680 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 405.91 408.7975
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 46200 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 409.3725 410.0025
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 10080 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 410.055 410.222741
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 2683 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 410.08 410.2425
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 2600 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 410.222741 410.452741
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 3680 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 410.2425 410.495
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 4040 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 410.452741 411.6525
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 19197 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 411.2925 412.811001
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 24296 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 412.972741 414.102741
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 18080 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 413.945 414.22
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 4400 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 414.102741 414.4575
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 5677 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 414.22 414.6075
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 6200 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 414.4575 414.765
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 4920 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 414.6075 415.005
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 6360 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 415.602741 420.3525
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 75997 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 420.0075 421.556773
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 24788 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 422.64 424.015
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 22000 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 424.200868 424.360868
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 2560 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 424.24 424.4275
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 3000 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 424.360868 424.730868
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 5920 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 424.5925 426.607306
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 32236 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 427.3025 428.6075
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 20880 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 428.817306 429.08
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 4204 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 428.8875 429.2675
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 6080 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 429.315 432.887306
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 57156 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 432.6675 432.9175
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 4000 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 432.887306 433.117306
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 3680 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 432.9175 433.188436
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 4334 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 433.117306 433.81
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 11084 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 433.37 450.005578
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 266169 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 450.39 451.4475
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 16920 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 451.345578 454.595578
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 52000 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 454.7125 455.17
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 7320 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 457.224392 462.7375
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 88210 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 462.63 463.08
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 7200 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 462.7375 463.40147
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 10623 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 463.5575 470.075
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 104280 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 469.93 470.4125
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 7720 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 470.075 470.4275
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 5640 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 470.4125 476.388835
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 95621 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 476.5075 481.4825
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 79600 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 482.255917 482.605888
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 5600 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 482.382065 482.973965
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 9470 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 482.9725 483.275917
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 4854 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 486.214923 487.555
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 21442 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 487.3075 488.073594
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 12257 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 495.071991 495.301991
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 3680 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.B.wav 499.45 504.0825
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 74120 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_01\s01.objects.1.A.wav 504.3475 504.765
# 1 2 16000 8281550 NONE not compressed
# 517.596875
# 6680 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_02\s02.objects.1.A.wav 22.9225 25.04
# 1 2 16000 28205471 NONE not compressed
# 1762.8419375
# 33880 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_02\s02.objects.1.B.wav 25.1975 25.71
# 1 2 16000 28205471 NONE not compressed
# 1762.8419375
# 8200 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_02\s02.objects.1.A.wav 25.5375 27.667266
# 1 2 16000 28205471 NONE not compressed
# 1762.8419375
# 34076 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_02\s02.objects.1.B.wav 27.9875 28.4925
# 1 2 16000 28205471 NONE not compressed
# 1762.8419375
# 8080 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_02\s02.objects.1.A.wav 28.992813 31.1075
# 1 2 16000 28205471 NONE not compressed
# 1762.8419375
# 33835 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_02\s02.objects.1.B.wav 32.955 33.44
# 1 2 16000 28205471 NONE not compressed
# 1762.8419375
# 7760 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_02\s02.objects.1.A.wav 33.695 34.785
# 1 2 16000 28205471 NONE not compressed
# 1762.8419375
# 17440 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_02\s02.objects.1.B.wav 40.3875 43.02
# 1 2 16000 28205471 NONE not compressed
# 1762.8419375
# 42120 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_02\s02.objects.1.A.wav 43.3125 72.37
# 1 2 16000 28205471 NONE not compressed
# 1762.8419375
# 464920 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_02\s02.objects.1.B.wav 80.2375 81.4925
# 1 2 16000 28205471 NONE not compressed
# 1762.8419375
# 20080 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_02\s02.objects.1.A.wav 81.9875 110.52
# 1 2 16000 28205471 NONE not compressed
# 1762.8419375
# 456520 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_02\s02.objects.1.B.wav 114.375 118.1825
# 1 2 16000 28205471 NONE not compressed
# 1762.8419375
# 60920 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_02\s02.objects.1.A.wav 118.41 123.5475
# 1 2 16000 28205471 NONE not compressed
# 1762.8419375
# 82200 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_02\s02.objects.1.B.wav 123.285 123.705
# 1 2 16000 28205471 NONE not compressed
# 1762.8419375
# 6720 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_02\s02.objects.1.A.wav 123.755 130.55681
# 1 2 16000 28205471 NONE not compressed
# 1762.8419375
# 108828 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_02\s02.objects.1.B.wav 130.725 132.435
# 1 2 16000 28205471 NONE not compressed
# 1762.8419375
# 27360 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_02\s02.objects.1.A.wav 132.815 133.74
# 1 2 16000 28205471 NONE not compressed
# 1762.8419375
# 14800 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_02\s02.objects.1.B.wav 133.03 133.845
# 1 2 16000 28205471 NONE not compressed
# 1762.8419375
# 13040 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_02\s02.objects.1.A.wav 135.0225 140.2725
# 1 2 16000 28205471 NONE not compressed
# 1762.8419375
# 84000 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_02\s02.objects.1.B.wav 140.225 140.6775
# 1 2 16000 28205471 NONE not compressed
# 1762.8419375
# 7240 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_02\s02.objects.1.A.wav 140.605 148.7275
# 1 2 16000 28205471 NONE not compressed
# 1762.8419375
# 129960 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_02\s02.objects.1.B.wav 150.7225 151.1475
# 1 2 16000 28205471 NONE not compressed
# 1762.8419375
# 6800 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_02\s02.objects.1.A.wav 153.5275 178.204982
# 1 2 16000 28205471 NONE not compressed
# 1762.8419375
# 394839 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_02\s02.objects.1.B.wav 178.7275 179.233409
# 1 2 16000 28205471 NONE not compressed
# 1762.8419375
# 8094 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_02\s02.objects.1.A.wav 179.195 179.549549
# 1 2 16000 28205471 NONE not compressed
# 1762.8419375
# 5672 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_02\s02.objects.1.B.wav 179.233409 179.635
# 1 2 16000 28205471 NONE not compressed
# 1762.8419375
# 6426 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_02\s02.objects.1.A.wav 179.84 183.92
# 1 2 16000 28205471 NONE not compressed
# 1762.8419375
# 65280 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_02\s02.objects.1.B.wav 186.365 187.47
# 1 2 16000 28205471 NONE not compressed
# 1762.8419375
# 17680 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_02\s02.objects.1.A.wav 187.920897 188.6925
# 1 2 16000 28205471 NONE not compressed
# 1762.8419375
# 12346 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_02\s02.objects.1.B.wav 188.467195 191.9375
# 1 2 16000 28205471 NONE not compressed
# 1762.8419375
# 55525 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_02\s02.objects.1.A.wav 193.56 194.23
# 1 2 16000 28205471 NONE not compressed
# 1762.8419375
# 10720 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_02\s02.objects.1.B.wav 195.055 196.5125
# 1 2 16000 28205471 NONE not compressed
# 1762.8419375
# 23320 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_02\s02.objects.1.A.wav 196.955 197.2325
# 1 2 16000 28205471 NONE not compressed
# 1762.8419375
# 4440 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_02\s02.objects.1.B.wav 197.6 200.477195
# 1 2 16000 28205471 NONE not compressed
# 1762.8419375
# 46035 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_02\s02.objects.1.A.wav 200.485 221.09
# 1 2 16000 28205471 NONE not compressed
# 1762.8419375
# 329680 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_02\s02.objects.1.B.wav 226.2225 232.5175
# 1 2 16000 28205471 NONE not compressed
# 1762.8419375
# 100720 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_02\s02.objects.1.A.wav 232.355 234.65
# 1 2 16000 28205471 NONE not compressed
# 1762.8419375
# 36720 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_02\s02.objects.1.B.wav 234.3525 234.885
# 1 2 16000 28205471 NONE not compressed
# 1762.8419375
# 8520 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_02\s02.objects.1.A.wav 234.87 252.375
# 1 2 16000 28205471 NONE not compressed
# 1762.8419375
# 280080 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_02\s02.objects.1.B.wav 252.225 252.555
# 1 2 16000 28205471 NONE not compressed
# 1762.8419375
# 5280 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_02\s02.objects.1.A.wav 252.375 254.07
# 1 2 16000 28205471 NONE not compressed
# 1762.8419375
# 27120 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_02\s02.objects.1.B.wav 254.0875 254.3525
# 1 2 16000 28205471 NONE not compressed
# 1762.8419375
# 4240 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_02\s02.objects.1.A.wav 254.5125 261.6525
# 1 2 16000 28205471 NONE not compressed
# 1762.8419375
# 114239 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_02\s02.objects.1.B.wav 263.1625 264.401996
# 1 2 16000 28205471 NONE not compressed
# 1762.8419375
# 19831 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_02\s02.objects.1.A.wav 265.2925 266.305
# 1 2 16000 28205471 NONE not compressed
# 1762.8419375
# 16200 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_02\s02.objects.1.B.wav 266.5575 269.1475
# 1 2 16000 28205471 NONE not compressed
# 1762.8419375
# 41440 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_02\s02.objects.1.A.wav 269.16 272.675
# 1 2 16000 28205471 NONE not compressed
# 1762.8419375
# 56240 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_02\s02.objects.1.B.wav 275.207293 276.825
# 1 2 16000 28205471 NONE not compressed
# 1762.8419375
# 25884 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_02\s02.objects.1.A.wav 277.525 283.81
# 1 2 16000 28205471 NONE not compressed
# 1762.8419375
# 100560 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_02\s02.objects.1.B.wav 284.4625 288.4625
# 1 2 16000 28205471 NONE not compressed
# 1762.8419375
# 64000 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_02\s02.objects.1.A.wav 288.4175 288.975
# 1 2 16000 28205471 NONE not compressed
# 1762.8419375
# 8920 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_02\s02.objects.1.B.wav 288.4625 288.975
# 1 2 16000 28205471 NONE not compressed
# 1762.8419375
# 8200 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_02\s02.objects.1.A.wav 288.975 290.9375
# 1 2 16000 28205471 NONE not compressed
# 1762.8419375
# 31400 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_02\s02.objects.1.B.wav 290.805 291.17
# 1 2 16000 28205471 NONE not compressed
# 1762.8419375
# 5840 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_02\s02.objects.1.A.wav 290.9375 292.0275
# 1 2 16000 28205471 NONE not compressed
# 1762.8419375
# 17440 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_02\s02.objects.1.B.wav 291.795 292.1275
# 1 2 16000 28205471 NONE not compressed
# 1762.8419375
# 5320 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_02\s02.objects.1.A.wav 292.4725 297.889591
# 1 2 16000 28205471 NONE not compressed
# 1762.8419375
# 86673 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_02\s02.objects.1.B.wav 297.8075 298.2175
# 1 2 16000 28205471 NONE not compressed
# 1762.8419375
# 6560 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_02\s02.objects.1.A.wav 297.889591 298.8175
# 1 2 16000 28205471 NONE not compressed
# 1762.8419375
# 14847 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_02\s02.objects.1.B.wav 299.2175 299.777406
# 1 2 16000 28205471 NONE not compressed
# 1762.8419375
# 8958 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_02\s02.objects.1.A.wav 299.999591 313.135
# 1 2 16000 28205471 NONE not compressed
# 1762.8419375
# 210167 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_02\s02.objects.1.B.wav 313.0025 317.641493
# 1 2 16000 28205471 NONE not compressed
# 1762.8419375
# 74223 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_02\s02.objects.1.A.wav 317.3025 317.91
# 1 2 16000 28205471 NONE not compressed
# 1762.8419375
# 9720 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_02\s02.objects.1.B.wav 317.884237 318.845
# 1 2 16000 28205471 NONE not compressed
# 1762.8419375
# 15373 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_02\s02.objects.1.A.wav 318.8725 319.15
# 1 2 16000 28205471 NONE not compressed
# 1762.8419375
# 4440 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_02\s02.objects.1.B.wav 319.127875 320.9925
# 1 2 16000 28205471 NONE not compressed
# 1762.8419375
# 29834 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_02\s02.objects.1.A.wav 320.965 323.8825
# 1 2 16000 28205471 NONE not compressed
# 1762.8419375
# 46680 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_02\s02.objects.1.B.wav 326.470212 336.725
# 1 2 16000 28205471 NONE not compressed
# 1762.8419375
# 164077 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_02\s02.objects.1.A.wav 336.557502 338.1425
# 1 2 16000 28205471 NONE not compressed
# 1762.8419375
# 25360 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_02\s02.objects.1.B.wav 338.210212 338.6775
# 1 2 16000 28205471 NONE not compressed
# 1762.8419375
# 7477 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_02\s02.objects.1.A.wav 338.4 338.557502
# 1 2 16000 28205471 NONE not compressed
# 1762.8419375
# 2520 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_02\s02.objects.1.B.wav 338.6775 340.1525
# 1 2 16000 28205471 NONE not compressed
# 1762.8419375
# 23600 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_02\s02.objects.1.A.wav 339.6175 340.2025
# 1 2 16000 28205471 NONE not compressed
# 1762.8419375
# 9360 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_02\s02.objects.1.B.wav 340.1525 340.6825
# 1 2 16000 28205471 NONE not compressed
# 1762.8419375
# 8480 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_02\s02.objects.1.A.wav 340.2025 340.7075
# 1 2 16000 28205471 NONE not compressed
# 1762.8419375
# 8080 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_02\s02.objects.1.B.wav 348.217993 352.3225
# 1 2 16000 28205471 NONE not compressed
# 1762.8419375
# 65673 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_02\s02.objects.1.A.wav 354.525 355.6925
# 1 2 16000 28205471 NONE not compressed
# 1762.8419375
# 18680 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_02\s02.objects.1.B.wav 354.585 355.21
# 1 2 16000 28205471 NONE not compressed
# 1762.8419375
# 10000 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_02\s02.objects.1.A.wav 355.6925 358.9725
# 1 2 16000 28205471 NONE not compressed
# 1762.8419375
# 52480 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_02\s02.objects.1.B.wav 360.0225 360.875
# 1 2 16000 28205471 NONE not compressed
# 1762.8419375
# 13640 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_02\s02.objects.1.A.wav 361.5225 362.0325
# 1 2 16000 28205471 NONE not compressed
# 1762.8419375
# 8160 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_02\s02.objects.1.B.wav 361.645 362.39
# 1 2 16000 28205471 NONE not compressed
# 1762.8419375
# 11920 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_02\s02.objects.1.A.wav 368.700327 370.0625
# 1 2 16000 28205471 NONE not compressed
# 1762.8419375
# 21795 16000
# ...
# 36680 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_12\s12.objects.1.A.wav 843.6275 865.21
# 1 2 16000 19614346 NONE not compressed
# 1225.896625
# 345320 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_12\s12.objects.1.B.wav 867.319264 868.2925
# 1 2 16000 19614346 NONE not compressed
# 1225.896625
# 15572 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_12\s12.objects.1.A.wav 868.33 879.5025
# 1 2 16000 19614346 NONE not compressed
# 1225.896625
# 178760 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_12\s12.objects.1.B.wav 879.87 880.1325
# 1 2 16000 19614346 NONE not compressed
# 1225.896625
# 4200 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_12\s12.objects.1.A.wav 880.2125 885.5125
# 1 2 16000 19614346 NONE not compressed
# 1225.896625
# 84800 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_12\s12.objects.1.B.wav 886.325735 895.181032
# 1 2 16000 19614346 NONE not compressed
# 1225.896625
# 141685 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_12\s12.objects.1.A.wav 895.1425 895.66
# 1 2 16000 19614346 NONE not compressed
# 1225.896625
# 8280 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_12\s12.objects.1.B.wav 895.181032 895.443297
# 1 2 16000 19614346 NONE not compressed
# 1225.896625
# 4196 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_12\s12.objects.1.A.wav 895.66 901.4275
# 1 2 16000 19614346 NONE not compressed
# 1225.896625
# 92280 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_12\s12.objects.1.B.wav 902.10174 904.899278
# 1 2 16000 19614346 NONE not compressed
# 1225.896625
# 44761 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_12\s12.objects.1.A.wav 904.7025 905.5075
# 1 2 16000 19614346 NONE not compressed
# 1225.896625
# 12880 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_12\s12.objects.1.B.wav 906.211585 907.198935
# 1 2 16000 19614346 NONE not compressed
# 1225.896625
# 15797 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_12\s12.objects.1.A.wav 906.94 909.4625
# 1 2 16000 19614346 NONE not compressed
# 1225.896625
# 40360 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_12\s12.objects.1.B.wav 910.370797 912.405
# 1 2 16000 19614346 NONE not compressed
# 1225.896625
# 32548 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_12\s12.objects.1.A.wav 912.3175 912.585
# 1 2 16000 19614346 NONE not compressed
# 1225.896625
# 4280 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_12\s12.objects.1.B.wav 912.405 912.73
# 1 2 16000 19614346 NONE not compressed
# 1225.896625
# 5200 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_12\s12.objects.1.A.wav 912.585 912.805
# 1 2 16000 19614346 NONE not compressed
# 1225.896625
# 3520 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_12\s12.objects.1.B.wav 912.73 912.795
# 1 2 16000 19614346 NONE not compressed
# 1225.896625
# 1040 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_12\s12.objects.1.A.wav 912.805 916.125
# 1 2 16000 19614346 NONE not compressed
# 1225.896625
# 53120 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_12\s12.objects.1.B.wav 916.2475 916.5575
# 1 2 16000 19614346 NONE not compressed
# 1225.896625
# 4960 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_12\s12.objects.1.A.wav 916.37 916.8375
# 1 2 16000 19614346 NONE not compressed
# 1225.896625
# 7480 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_12\s12.objects.1.B.wav 923.8925 928.5675
# 1 2 16000 19614346 NONE not compressed
# 1225.896625
# 74800 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_12\s12.objects.1.A.wav 928.6625 929.075
# 1 2 16000 19614346 NONE not compressed
# 1225.896625
# 6600 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_12\s12.objects.1.B.wav 929.1025 935.67781
# 1 2 16000 19614346 NONE not compressed
# 1225.896625
# 105204 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_12\s12.objects.1.A.wav 935.585 935.9125
# 1 2 16000 19614346 NONE not compressed
# 1225.896625
# 5240 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_12\s12.objects.1.B.wav 935.67781 936.40781
# 1 2 16000 19614346 NONE not compressed
# 1225.896625
# 11680 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_12\s12.objects.1.A.wav 936.695 937.019022
# 1 2 16000 19614346 NONE not compressed
# 1225.896625
# 5184 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_12\s12.objects.1.B.wav 937.93781 941.365
# 1 2 16000 19614346 NONE not compressed
# 1225.896625
# 54836 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_12\s12.objects.1.A.wav 941.7575 943.2375
# 1 2 16000 19614346 NONE not compressed
# 1225.896625
# 23680 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_12\s12.objects.1.B.wav 943.8825 944.8
# 1 2 16000 19614346 NONE not compressed
# 1225.896625
# 14680 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_12\s12.objects.1.A.wav 944.585 944.8125
# 1 2 16000 19614346 NONE not compressed
# 1225.896625
# 3640 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_12\s12.objects.1.B.wav 944.8 955.82781
# 1 2 16000 19614346 NONE not compressed
# 1225.896625
# 176444 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_12\s12.objects.1.A.wav 956.3975 959.2975
# 1 2 16000 19614346 NONE not compressed
# 1225.896625
# 46400 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_12\s12.objects.1.B.wav 959.901012 960.545
# 1 2 16000 19614346 NONE not compressed
# 1225.896625
# 10304 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_12\s12.objects.1.A.wav 960.7775 961.79
# 1 2 16000 19614346 NONE not compressed
# 1225.896625
# 16200 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_12\s12.objects.1.B.wav 962.0925 973.1625
# 1 2 16000 19614346 NONE not compressed
# 1225.896625
# 177120 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_12\s12.objects.1.A.wav 974.085 974.5925
# 1 2 16000 19614346 NONE not compressed
# 1225.896625
# 8120 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_12\s12.objects.1.B.wav 974.7675 977.22
# 1 2 16000 19614346 NONE not compressed
# 1225.896625
# 39240 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_12\s12.objects.1.A.wav 977.77 978.1175
# 1 2 16000 19614346 NONE not compressed
# 1225.896625
# 5560 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_12\s12.objects.1.B.wav 979.033395 986.240068
# 1 2 16000 19614346 NONE not compressed
# 1225.896625
# 115307 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_12\s12.objects.1.A.wav 986.8225 990.445
# 1 2 16000 19614346 NONE not compressed
# 1225.896625
# 57960 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_12\s12.objects.1.B.wav 990.3975 990.623163
# 1 2 16000 19614346 NONE not compressed
# 1225.896625
# 3610 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_12\s12.objects.1.A.wav 990.445 990.8175
# 1 2 16000 19614346 NONE not compressed
# 1225.896625
# 5960 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_12\s12.objects.1.B.wav 990.623163 990.86059
# 1 2 16000 19614346 NONE not compressed
# 1225.896625
# 3799 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_12\s12.objects.1.A.wav 995.67 1026.8325
# 1 2 16000 19614346 NONE not compressed
# 1225.896625
# 498600 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_12\s12.objects.1.B.wav 1027.085 1027.389917
# 1 2 16000 19614346 NONE not compressed
# 1225.896625
# 4878 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_12\s12.objects.1.A.wav 1027.21 1038.645
# 1 2 16000 19614346 NONE not compressed
# 1225.896625
# 182960 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_12\s12.objects.1.B.wav 1038.7375 1039.1675
# 1 2 16000 19614346 NONE not compressed
# 1225.896625
# 6880 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_12\s12.objects.1.A.wav 1038.9725 1040.01
# 1 2 16000 19614346 NONE not compressed
# 1225.896625
# 16600 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_12\s12.objects.1.B.wav 1040.4075 1040.7325
# 1 2 16000 19614346 NONE not compressed
# 1225.896625
# 5200 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_12\s12.objects.1.A.wav 1040.705 1047.3725
# 1 2 16000 19614346 NONE not compressed
# 1225.896625
# 106681 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_12\s12.objects.1.B.wav 1048.3575 1048.7725
# 1 2 16000 19614346 NONE not compressed
# 1225.896625
# 6640 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_12\s12.objects.1.A.wav 1048.9225 1052.385
# 1 2 16000 19614346 NONE not compressed
# 1225.896625
# 55400 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_12\s12.objects.1.B.wav 1052.876894 1055.505
# 1 2 16000 19614346 NONE not compressed
# 1225.896625
# 42050 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_12\s12.objects.1.A.wav 1056.755 1063.29
# 1 2 16000 19614346 NONE not compressed
# 1225.896625
# 104560 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_12\s12.objects.1.B.wav 1063.495 1063.74
# 1 2 16000 19614346 NONE not compressed
# 1225.896625
# 3920 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_12\s12.objects.1.A.wav 1063.805 1071.8625
# 1 2 16000 19614346 NONE not compressed
# 1225.896625
# 128920 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_12\s12.objects.1.B.wav 1072.3 1072.4925
# 1 2 16000 19614346 NONE not compressed
# 1225.896625
# 3080 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_12\s12.objects.1.A.wav 1072.3575 1080.0325
# 1 2 16000 19614346 NONE not compressed
# 1225.896625
# 122800 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_12\s12.objects.1.B.wav 1080.33 1084.965
# 1 2 16000 19614346 NONE not compressed
# 1225.896625
# 74160 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_12\s12.objects.1.A.wav 1084.865659 1085.289396
# 1 2 16000 19614346 NONE not compressed
# 1225.896625
# 6780 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_12\s12.objects.1.B.wav 1084.965 1085.388193
# 1 2 16000 19614346 NONE not compressed
# 1225.896625
# 6771 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_12\s12.objects.1.A.wav 1085.289396 1086.995
# 1 2 16000 19614346 NONE not compressed
# 1225.896625
# 27290 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_12\s12.objects.1.B.wav 1087.4775 1089.35
# 1 2 16000 19614346 NONE not compressed
# 1225.896625
# 29960 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_12\s12.objects.1.A.wav 1089.2375 1090.5625
# 1 2 16000 19614346 NONE not compressed
# 1225.896625
# 21200 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_12\s12.objects.1.B.wav 1099.760161 1108.920161
# 1 2 16000 19614346 NONE not compressed
# 1225.896625
# 146560 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_12\s12.objects.1.A.wav 1108.81 1109.215
# 1 2 16000 19614346 NONE not compressed
# 1225.896625
# 6480 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_12\s12.objects.1.B.wav 1108.920161 1109.3425
# 1 2 16000 19614346 NONE not compressed
# 1225.896625
# 6758 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_12\s12.objects.1.A.wav 1109.215 1109.88
# 1 2 16000 19614346 NONE not compressed
# 1225.896625
# 10640 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_12\s12.objects.1.B.wav 1109.3425 1109.75
# 1 2 16000 19614346 NONE not compressed
# 1225.896625
# 6520 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_12\s12.objects.1.A.wav 1109.88 1112.325
# 1 2 16000 19614346 NONE not compressed
# 1225.896625
# 39120 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_12\s12.objects.1.B.wav 1112.8225 1118.250161
# 1 2 16000 19614346 NONE not compressed
# 1225.896625
# 86842 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_12\s12.objects.1.A.wav 1118.0325 1119.0275
# 1 2 16000 19614346 NONE not compressed
# 1225.896625
# 15920 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_12\s12.objects.1.B.wav 1119.640161 1128.900198
# 1 2 16000 19614346 NONE not compressed
# 1225.896625
# 148161 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_12\s12.objects.1.A.wav 1128.5175 1128.82
# 1 2 16000 19614346 NONE not compressed
# 1225.896625
# 4840 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_12\s12.objects.1.B.wav 1128.900198 1130.770198
# 1 2 16000 19614346 NONE not compressed
# 1225.896625
# 29920 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_12\s12.objects.1.A.wav 1130.965 1131.165
# 1 2 16000 19614346 NONE not compressed
# 1225.896625
# 3200 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_12\s12.objects.1.B.wav 1131.710198 1143.3075
# 1 2 16000 19614346 NONE not compressed
# 1225.896625
# 185557 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_12\s12.objects.1.A.wav 1144.95 1151.3525
# 1 2 16000 19614346 NONE not compressed
# 1225.896625
# 102440 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_12\s12.objects.1.B.wav 1151.7175 1152.1375
# 1 2 16000 19614346 NONE not compressed
# 1225.896625
# 6720 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_12\s12.objects.1.A.wav 1151.745 1153.005
# 1 2 16000 19614346 NONE not compressed
# 1225.896625
# 20160 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_12\s12.objects.1.B.wav 1152.95 1153.72
# 1 2 16000 19614346 NONE not compressed
# 1225.896625
# 12320 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_12\s12.objects.1.A.wav 1153.005 1153.9075
# 1 2 16000 19614346 NONE not compressed
# 1225.896625
# 14440 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_12\s12.objects.1.B.wav 1154.9325 1172.84
# 1 2 16000 19614346 NONE not compressed
# 1225.896625
# 286520 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_12\s12.objects.1.A.wav 1172.615 1173.0225
# 1 2 16000 19614346 NONE not compressed
# 1225.896625
# 6520 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_12\s12.objects.1.B.wav 1174.559162 1188.7
# 1 2 16000 19614346 NONE not compressed
# 1225.896625
# 226254 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_12\s12.objects.1.A.wav 1188.96 1189.5275
# 1 2 16000 19614346 NONE not compressed
# 1225.896625
# 9080 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_12\s12.objects.1.B.wav 1189.685 1190.869162
# 1 2 16000 19614346 NONE not compressed
# 1225.896625
# 18946 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_12\s12.objects.1.A.wav 1190.5675 1190.915
# 1 2 16000 19614346 NONE not compressed
# 1225.896625
# 5560 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_12\s12.objects.1.B.wav 1190.869162 1190.959161
# 1 2 16000 19614346 NONE not compressed
# 1225.896625
# 1440 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_12\s12.objects.1.A.wav 1190.915 1191.1825
# 1 2 16000 19614346 NONE not compressed
# 1225.896625
# 4280 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_12\s12.objects.1.B.wav 1190.959161 1192.041591
# 1 2 16000 19614346 NONE not compressed
# 1225.896625
# 17319 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_12\s12.objects.1.A.wav 1194.7525 1196.6725
# 1 2 16000 19614346 NONE not compressed
# 1225.896625
# 30720 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_12\s12.objects.1.B.wav 1196.3725 1196.84
# 1 2 16000 19614346 NONE not compressed
# 1225.896625
# 7480 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_12\s12.objects.1.A.wav 1196.6725 1197.045
# 1 2 16000 19614346 NONE not compressed
# 1225.896625
# 5960 16000
# get_TRILLv3_signal: D:\Jay\columbia-games-corpus\data\session_12\s12.objects.1.B.wav 1197.4425 1198.0475
# 1 2 16000 19614346 NONE not compressed
# 1225.896625
# 9680 16000

# %%
#Sixth step 
## Program to measure lexical and syntactic entrainment
## The program takes two turns as input and provides cosine similarity as output

# ------------------------------------------------------------------------
# Name : Syntactic_and_Lexical_similarity_en.py
# Author : Jay Kejriwal
# Date   : 21-03-2022
# Description : Program to measure lexical and syntactic similarity between two sentences
# ------------------------------------------------------------------------

import stanza
import re
import math
from collections import Counter
import nltk
from nltk.util import ngrams
nlp = stanza.Pipeline(lang='en', processors='tokenize,pos,lemma')

def get_cosine(vec1, vec2):      #Function to measure cosine similarity
    intersection = set(vec1.keys()) & set(vec2.keys())
    numerator = sum([vec1[x] * vec2[x] for x in intersection])
    sum1 = sum([vec1[x] ** 2 for x in list(vec1.keys())])
    sum2 = sum([vec2[x] ** 2 for x in list(vec2.keys())])
    denominator = math.sqrt(sum1) * math.sqrt(sum2)
    if not denominator:
        return 0.0
    else:
        return float(numerator) / denominator

def text_to_vector(text,ngram):  #Function to measure lexical similarities in sentence
    n_grams = ngrams(nltk.word_tokenize(text), ngram)
    new_sequence1 =  [ ' '.join(grams) for grams in n_grams]
    return Counter(new_sequence1)


def process_lex_text(text):         #Function to remove punctuation and extrat lemma and pos
    words = re.sub(r'[.,"\-?:!;]', '', text.lower())
    doc = nlp(words)
    x=[f'{word.lemma}' for sent in doc.sentences for word in sent.words]
    return ' '.join([str(elem) for elem in x])


def process_syn_text(text):         #Function to remove punctuation and extrat lemma and pos
    words = re.sub(r'[.,"\-?:!;]', '', text.lower())
    doc = nlp(words)
    l=[f'{word.upos}' for sent in doc.sentences for word in sent.words]
    return ' '.join([str(elem) for elem in l])

def calculate_lexical_similarity(text1, text2):
    process1 = process_lex_text(text1)
    process2 = process_lex_text(text2)
    vector1 = text_to_vector(process1,ngram=1)
    print(vector1)
    vector2 = text_to_vector(process2,ngram=1)
    cosine = get_cosine(vector1, vector2)
    return cosine

def calculate_syntactic_similarity(text1, text2):
    process1 = process_syn_text(text1)
    process2 = process_syn_text(text2)
    vector1 = text_to_vector(process1,ngram=2)
    vector2 = text_to_vector(process2,ngram=2)
    cosin = get_cosine(vector1, vector2)
    return cosin

text1="on the top"
text2="I don't have anything like that"


# okay B -1
# 2 and right above the owl A-1
# 3 mmhm B -1
# 4 okay so uh the lawnmower -1 A
# 5 mmhm -1 B
# 6 okay so the ear -1A
# 7 mmhm -1 B
# 8 to them
print(calculate_lexical_similarity(text1, text2))
print(calculate_syntactic_similarity(text1, text2))
# Out:
# 2024-01-01 14:54:37 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.5.0.json:   0%|   …
# 2024-01-01 14:54:38 INFO: Loading these models for language: en (English):
# ========================
# | Processor | Package  |
# ------------------------
# | tokenize  | combined |
# | pos       | combined |
# | lemma     | combined |
# ========================
#
# 2024-01-01 14:54:38 INFO: Using device: cpu
# 2024-01-01 14:54:38 INFO: Loading: tokenize
# 2024-01-01 14:54:38 INFO: Loading: pos
# 2024-01-01 14:54:38 INFO: Loading: lemma
# 2024-01-01 14:54:38 INFO: Done loading processors!
# Counter({'on': 1, 'the': 1, 'top': 1})
# 0.0
# 0.0

# %%
#Seventh step 
## Program to measure entrainment distance using textual, semantic and auditory embeddings
## The program reads pkl file generated in the Fifth step and measures adjacent and non-adjacent scores at lexical, syntactic, semantic and acoustic levels
## The program also measures self score of both the speakers at all four linguistic levels
## The program generates a text file for each session with the following column information
### Same_pair_lexical [adjacent scores lexical] Not_Same_Pair_lexical [non-adjacent scores lexical]
### Same_pair_syntactic [adjacent scores lexical] Not_Same_Pair_syntactic [non-adjacent scores lexical]
### Same_pair_semantic [adjacent scores lexical] Not_Same_Pair_semantic [non-adjacent scores lexical]
### Same_pair_audio [adjacent scores acoustic]  Not_Same_Pair_audio [non-adjacent scores acoustic]  
###
### Speaker1_lexical_self_distance [Self score lexical Speaker 1] Speaker2_lexical_self_distance [Self score lexical Speaker 2]
### Speaker1_syntactic_self_distance [Self score syntactic Speaker 1] Speaker2_syntactic_self_distance [Self score syntactic Speaker 1]
### Speaker1_semantic_self_distance [Self score semantic Speaker 1] Speaker2_semantic_self_distance [Self score semantic Speaker 2]
### Speaker1_audio_self_distance    [Self score acoustic Speaker 1] Speaker2_audio_self_distance [Self score acoustic Speaker 2]


#Program to measure entrainment distance using cosine similarity
import pandas as pd
import csv
from sklearn.metrics.pairwise import cosine_similarity
from sentence_transformers import util
import random
import subprocess
import re
import glob
import os,sys
import numpy as np
import pickle

#Define path of embedding files generated in Fifth step 
audio_embedding_path = 'D:\\Jay\\columbia-games-corpus\\Pickle\\audio\\'
text_embedding_path = 'D:\\Jay\\columbia-games-corpus\\Pickle\\text\\'
semantic_embedding_path = 'D:\\Jay\\columbia-games-corpus\\Pickle\\semantic\\'

#Specify the output path where output needs to be saved
output_path = 'D:\\Jay\\columbia-games-corpus\\output\\'

for audiofile,textfile,semanticfile in zip(os.listdir(audio_embedding_path),os.listdir(text_embedding_path),os.listdir(semantic_embedding_path)):
        if audiofile.endswith(".pkl") & textfile.endswith(".pkl") & semanticfile.endswith(".pkl"):
            current_audiofile = os.path.join(audio_embedding_path,audiofile)
            current_textfile = os.path.join(text_embedding_path,textfile)
            current_semanticfile = os.path.join(semantic_embedding_path,semanticfile)

            output_filename= os.path.splitext(os.path.join(output_path, os.path.basename(audiofile)))[0]
            #Open audio, text and semantic pickle files
            with open(current_audiofile, 'rb') as a, open(current_textfile, 'rb') as b, open(current_semanticfile, 'rb') as c:
                audio_embeddings_tensor=pickle.load(a)
                sentence_embeddings_tensor=pickle.load(b)
                semantic_embeddings_tensor=pickle.load(c)

                sentence_embedding_random = []
                semantic_embedding_random = []
                audio_embedding_random = []
                
                lexical_speaker1=[]
                lexical_speaker2=[]
                syntactic_speaker1=[]
                syntactic_speaker2=[]
                semantic_speaker1=[]
                semantic_speaker2=[]
                audio_speaker1=[]
                audio_speaker2=[]
                
                same_pair_lexical = []
                not_samepairs_lexical_array = []
                not_samepairs_lexical=[]
                same_pairs_syntactic = []
                not_samepairs_syntactic_array = []
                not_samepairs_syntactic=[]
                same_pairs_semantic = []
                not_samepairs_semantic_array = []
                not_samepairs_semantic=[]
                same_pairs_audio = []
                not_samepairs_audio_array = []
                not_samepairs_audio=[]
                
                for i in range(0, len(sentence_embeddings_tensor)-1):
                    #Condition for random turns to exclude current and next turn 
                    sentence_embedding_random = [item for item in sentence_embeddings_tensor if np.logical_and(
                                                 item!=sentence_embeddings_tensor[i] , item != sentence_embeddings_tensor[i+1])]
                    audio_embedding_random = [item for item in audio_embeddings_tensor if np.logical_and(
                                                 item!=audio_embeddings_tensor[i] , item != audio_embeddings_tensor[i+1])]
                    semantic_embedding_random = [item for item in semantic_embeddings_tensor if np.logical_and(
                                                 item!=semantic_embeddings_tensor[i] , item != semantic_embeddings_tensor[i+1])]

                    if(i%2==0):
                        #Measure Adjacent score for even turns
                        spl=calculate_lexical_similarity(sentence_embeddings_tensor[i],sentence_embeddings_tensor[i+1])
                        same_pair_lexical.append(spl)
                        spsy=calculate_syntactic_similarity(sentence_embeddings_tensor[i],sentence_embeddings_tensor[i+1])
                        same_pairs_syntactic.append(spsy)
                        sps=util.cos_sim(semantic_embeddings_tensor[i],semantic_embeddings_tensor[i+1]).item()
                        same_pairs_semantic.append(sps)
                        spa=util.cos_sim(audio_embeddings_tensor[i],audio_embeddings_tensor[i+1]).item()
                        same_pairs_audio.append(spa)
                        
                        for x in range(10):
                            #Measure Non-adjacent score for odd turns
                            #Here, mean Non-adjacent score is measured on 10 random turns
                            nspla=calculate_lexical_similarity(sentence_embeddings_tensor[i],sentence_embedding_random[random.randrange(1,len(sentence_embedding_random),2)])
                            not_samepairs_lexical_array.append(nspla)
                            nspsya=calculate_syntactic_similarity(sentence_embeddings_tensor[i],sentence_embedding_random[random.randrange(1,len(sentence_embedding_random),2)])
                            not_samepairs_syntactic_array.append(nspsya)
                            nspsa=util.cos_sim(semantic_embeddings_tensor[i],semantic_embedding_random[random.randrange(1,len(semantic_embedding_random),2)]).item()
                            not_samepairs_semantic_array.append(nspsa)
                            nspaa=util.cos_sim(audio_embeddings_tensor[i],audio_embedding_random[random.randrange(1,len(audio_embedding_random),2)]).item()
                            not_samepairs_audio_array.append(nspaa)

                        nspl = np.mean(not_samepairs_lexical_array)
                        nspsy = np.mean(not_samepairs_syntactic_array)
                        nsps = np.mean(not_samepairs_semantic_array)
                        nspa = np.mean(not_samepairs_audio_array)

                        not_samepairs_lexical_array = []
                        not_samepairs_syntactic_array = []
                        not_samepairs_semantic_array = []
                        not_samepairs_audio_array = []

                        not_samepairs_lexical.append(nspl)
                        not_samepairs_syntactic.append(nspsy)
                        not_samepairs_semantic.append(nsps)                       
                        not_samepairs_audio.append(nspa)

                    elif(i%2!=0):
                        #Measure Adjacent score for odd turns
                        spl=calculate_lexical_similarity(sentence_embeddings_tensor[i],sentence_embeddings_tensor[i+1])
                        same_pair_lexical.append(spl)
                        spsy=calculate_syntactic_similarity(sentence_embeddings_tensor[i],sentence_embeddings_tensor[i+1])
                        same_pairs_syntactic.append(spsy)
                        sps=util.cos_sim(semantic_embeddings_tensor[i],semantic_embeddings_tensor[i+1]).item()
                        same_pairs_semantic.append(sps)
                        spa=util.cos_sim(audio_embeddings_tensor[i],audio_embeddings_tensor[i+1]).item()
                        same_pairs_audio.append(spa)

                        
                        for x in range(10):
                            #Measure Non-adjacent score for odd turns
                            #Here, mean Non-adjacent score is measured on 10 random turns
                            nspla=calculate_lexical_similarity(sentence_embeddings_tensor[i],sentence_embedding_random[random.randrange(0,len(sentence_embedding_random),2)])
                            not_samepairs_lexical_array.append(nspla)
                            nspsya=calculate_syntactic_similarity(sentence_embeddings_tensor[i],sentence_embedding_random[random.randrange(0,len(sentence_embedding_random),2)])
                            not_samepairs_syntactic_array.append(nspsya)
                            nspsa=util.cos_sim(semantic_embeddings_tensor[i],semantic_embedding_random[random.randrange(0,len(semantic_embedding_random),2)]).item()
                            not_samepairs_semantic_array.append(nspsa)
                            nspaa=util.cos_sim(audio_embeddings_tensor[i],audio_embedding_random[random.randrange(0,len(audio_embedding_random),2)]).item()
                            not_samepairs_audio_array.append(nspaa)


                        nspl = np.mean(not_samepairs_lexical_array)
                        nspsy = np.mean(not_samepairs_syntactic_array)
                        nsps = np.mean(not_samepairs_semantic_array)
                        nspa = np.mean(not_samepairs_audio_array)

                        not_samepairs_lexical_array = []
                        not_samepairs_syntactic_array = []
                        not_samepairs_semantic_array = []
                        not_samepairs_audio_array = []

                        not_samepairs_lexical.append(nspl)
                        not_samepairs_syntactic.append(nspsy)
                        not_samepairs_semantic.append(nsps)                       
                        not_samepairs_audio.append(nspa)

                for n in range(0, len(sentence_embeddings_tensor)-2):
                    #Measure self-scores
                    if(n%2==0):
                        same_spkr1_lexical=calculate_lexical_similarity(sentence_embeddings_tensor[n],sentence_embeddings_tensor[n+2])
                        lexical_speaker1.append(same_spkr1_lexical)
                        same_spkr1_syntactic=calculate_syntactic_similarity(sentence_embeddings_tensor[n],sentence_embeddings_tensor[n+2])
                        syntactic_speaker1.append(same_spkr1_syntactic)
                        same_spkr1_semantic=util.cos_sim(semantic_embeddings_tensor[n],semantic_embeddings_tensor[n+2]).item()
                        semantic_speaker1.append(same_spkr1_semantic)
                        same_spkr1_audio=util.cos_sim(audio_embeddings_tensor[n],audio_embeddings_tensor[n+2]).item()
                        audio_speaker1.append(same_spkr1_audio)
                
                    elif(n%2!=0):
                        same_spkr2_lexical=calculate_lexical_similarity(sentence_embeddings_tensor[n],sentence_embeddings_tensor[n+2])
                        lexical_speaker2.append(same_spkr2_lexical)
                        same_spkr2_syntactic=calculate_syntactic_similarity(sentence_embeddings_tensor[n],sentence_embeddings_tensor[n+2])
                        syntactic_speaker2.append(same_spkr2_syntactic)
                        same_spkr2_semantic=util.cos_sim(semantic_embeddings_tensor[n],semantic_embeddings_tensor[n+2]).item()
                        semantic_speaker2.append(same_spkr2_semantic)
                        same_spkr2_audio=util.cos_sim(audio_embeddings_tensor[n],audio_embeddings_tensor[n+2]).item()
                        audio_speaker2.append(same_spkr2_audio)
                        
                df = pd.DataFrame(data=None)
                df['Same_pair_lexical'] = pd.Series(same_pair_lexical)
                df['Not_Same_Pair_lexical'] = pd.Series(not_samepairs_lexical)
                df['Same_pair_syntactic'] = pd.Series(same_pairs_syntactic)
                df['Not_Same_Pair_syntactic'] = pd.Series(not_samepairs_syntactic)
                df['Same_pair_semantic'] = pd.Series(same_pairs_semantic)
                df['Not_Same_Pair_semantic'] = pd.Series(not_samepairs_semantic)
                df['Same_pair_audio'] = pd.Series(same_pairs_audio)
                df['Not_Same_Pair_audio'] = pd.Series(not_samepairs_audio)

                df['Speaker1_lexical_self_distance'] = pd.Series(lexical_speaker1)
                df['Speaker2_lexical_self_distance'] = pd.Series(lexical_speaker2)
                df['Speaker1_syntactic_self_distance'] = pd.Series(syntactic_speaker1)
                df['Speaker2_syntactic_self_distance'] = pd.Series(syntactic_speaker2)
                df['Speaker1_semantic_self_distance'] = pd.Series(semantic_speaker1)
                df['Speaker2_semantic_self_distance'] = pd.Series(semantic_speaker2)
                df['Speaker1_audio_self_distance'] = pd.Series(audio_speaker1)
                df['Speaker2_audio_self_distance'] = pd.Series(audio_speaker2)

                df.insert(0, 'Turn_number', range(1, 1 + len(df)))
                df.to_csv(output_filename, index=False,sep='\t')
               
                sentence_embedding_random = []
                semantic_embedding_random = []
                audio_embedding_random = []
                lexical_speaker1=[]
                lexical_speaker2=[]
                syntactic_speaker1=[]
                syntactic_speaker2=[]
                semantic_speaker1=[]
                semantic_speaker2=[]
                audio_speaker1=[]
                audio_speaker2=[]
                same_pair_lexical = []
                not_samepairs_lexical_array = []
                not_samepairs_lexical=[]
                same_pairs_syntactic = []
                not_samepairs_syntactic_array = []
                not_samepairs_syntactic=[]
                same_pairs_semantic = []
                not_samepairs_semantic_array = []
                not_samepairs_semantic=[]
                same_pairs_audio = []
                not_samepairs_audio_array = []
                not_samepairs_audio=[]
                del df,spl,spsy,sps,spa,nspl,nspsy,nsps,nspa,same_spkr1_lexical,
                same_spkr1_semantic,same_spkr1_syntactic,same_spkr1_audio,same_spkr2_lexical,
                same_spkr2_semantic,same_spkr2_syntactic,same_spkr2_audio

# %%
#Eight step 
## Program to measure proximity, convergence and syncrony using adjacent, non-adjacent and self-score obtained in Seventh step
## The program reads text file generated in Seventh step and statistically analyzes the data using different methods 
## For instance, Proximity at lexical, syntactic, semantic and acoustic level
## The program generates text file with following column information for each session


### Proximity 
# Proximity-t-value_lexical	Proximity-p-value_lexical	Proximity-p-value_lexical_adj	
# Proximity-t-value_syntactic	Proximity-p-value_syntactic	Proximity-p-value_syntactic_adj	
# Proximity-t-value_semantic	Proximity-p-value_semantic	Proximity-p-value_semantic_adj	
# Proximity-t-value_audio	Proximity-p-value_audio	Proximity-p-value_audio_adj	
### Convergence 
# Convergence-Pearson rho_lexical	Convergence-Pearson p-value_lexical	Convergence-Pearson p-value_lexical_adj	
# Convergence-Pearson rho_syntactic	Convergence-Pearson p-value_syntactic	Convergence-Pearson p-value_syntactic_adj	
# Convergence-Pearson rho_semantic	Convergence-Pearson p-value_semantic	Convergence-Pearson p-value_semantic_adj	
# Convergence-Pearson rho_audio	Convergence-Pearson p-value_audio	Convergence-Pearson p-value_audio_adj	
### Synchrony
# Syncrony-Pearson rho_lexical	Syncrony-Pearson p-value_lexical	Syncrony-Pearson p-value_lexical_adj	
# Syncrony-Pearson rho_syntactic	Syncrony-Pearson p-value_syntactic	Syncrony-Pearson p-value_syntactic_adj	
# Syncrony-Pearson rho_semantic	Syncrony-Pearson p-value_semantic	Syncrony-Pearson p-value_semantic_adj	
# Syncrony-Pearson rho_audio	Syncrony-Pearson p-value_audio	Syncrony-Pearson p-value_audio_adj
import numpy as np
import pandas as pd
import scipy
import pingouin as pg
from scipy.stats import ttest_ind
from math import sqrt
import sys
from scipy import stats
import os
import sys
import glob
import os.path
import pandas as pd
from statsmodels.stats.multitest import multipletests

#Specify path of input files generated at sixth step
list_of_files = glob.glob(r'D:\Jay\columbia-games-corpus\output\*.txt',recursive=True)

#Specify output path
output_path = r'D:\Jay\columbia-games-corpus\statsoutput'
for file_name in list_of_files:
    out_name= os.path.join(output_path, os.path.basename(file_name))
    csv_input = pd.read_csv(file_name, delimiter='\t')
    
    #Proximity
    proximity_lexical=stats.ttest_rel(csv_input['Same_pair_lexical'], csv_input['Not_Same_Pair_lexical'])
    csv_input['Proximity-t-value_lexical']= proximity_lexical.statistic
    csv_input['Proximity-p-value_lexical']= proximity_lexical.pvalue
    #Here, Bonferroni correction is applied. Since there were 12 sessions we divided the significance value (0.05) by nr. of sessions
    csv_input['Proximity-p-value_lexical_adj'] = csv_input['Proximity-p-value_lexical'].lt(0.05/12)

    proximity_syntactic=stats.ttest_rel(csv_input['Same_pair_syntactic'], csv_input['Not_Same_Pair_syntactic'])
    csv_input['Proximity-t-value_syntactic']= proximity_syntactic.statistic
    csv_input['Proximity-p-value_syntactic']= proximity_syntactic.pvalue
    #Bonferroni correction
    csv_input['Proximity-p-value_syntactic_adj'] = csv_input['Proximity-p-value_syntactic'].lt(0.05/12)

    proximity_semantic=stats.ttest_rel(csv_input['Same_pair_semantic'], csv_input['Not_Same_Pair_semantic'])
    csv_input['Proximity-t-value_semantic']= proximity_semantic.statistic
    csv_input['Proximity-p-value_semantic']= proximity_semantic.pvalue
    #Bonferroni correction
    csv_input['Proximity-p-value_semantic_adj'] = csv_input['Proximity-p-value_semantic'].lt(0.05/12)

    proximity_audio=stats.ttest_rel(csv_input['Same_pair_audio'], csv_input['Not_Same_Pair_audio'])
    csv_input['Proximity-t-value_audio']= proximity_audio.statistic
    csv_input['Proximity-p-value_audio']= proximity_audio.pvalue
    #Bonferroni correction
    csv_input['Proximity-p-value_audio_adj'] = csv_input['Proximity-p-value_audio'].lt(0.05/12)
    
    #Convergence
    convlexr,convlexp = stats.pearsonr(csv_input['Same_pair_lexical'], csv_input['Turn_number'])
    csv_input['Convergence-Pearson rho_lexical'] = convlexr
    csv_input['Convergence-Pearson p-value_lexical'] = convlexp
    #Bonferroni correction
    csv_input['Convergence-Pearson p-value_lexical_adj'] = csv_input['Convergence-Pearson p-value_lexical'].lt(0.05/12)

    convsynr,convsynp = stats.pearsonr(csv_input['Same_pair_syntactic'], csv_input['Turn_number'])
    csv_input['Convergence-Pearson rho_syntactic'] = convsynr
    csv_input['Convergence-Pearson p-value_syntactic'] = convsynp
    #Bonferroni correction
    csv_input['Convergence-Pearson p-value_syntactic_adj'] = csv_input['Convergence-Pearson p-value_syntactic'].lt(0.05/12)

    convsemr,convsemp = stats.pearsonr(csv_input['Same_pair_semantic'], csv_input['Turn_number'])
    csv_input['Convergence-Pearson rho_semantic'] = convsemr
    csv_input['Convergence-Pearson p-value_semantic'] = convsemp
    #Bonferroni correction
    csv_input['Convergence-Pearson p-value_semantic_adj'] = csv_input['Convergence-Pearson p-value_semantic'].lt(0.05/12)

    convaudior,convaudiop = stats.pearsonr(csv_input['Same_pair_audio'], csv_input['Turn_number'])
    csv_input['Convergence-Pearson rho_audio'] = convaudior
    csv_input['Convergence-Pearson p-value_audio'] = convaudiop
    #Bonferroni correction
    csv_input['Convergence-Pearson p-value_audio_adj'] = csv_input['Convergence-Pearson p-value_audio'].lt(0.05/12)

    #Synchrony

    csv_input.dropna(inplace=True)
    synclexr,synclexp = stats.pearsonr(csv_input['Speaker1_lexical_self_distance'], csv_input['Speaker2_lexical_self_distance'])
    csv_input['Syncrony-Pearson rho_lexical'] = synclexr
    csv_input['Syncrony-Pearson p-value_lexical'] = synclexp
    #Bonferroni correction
    csv_input['Syncrony-Pearson p-value_lexical_adj'] = csv_input['Syncrony-Pearson p-value_lexical'].lt(0.05/12)

    syncsynr,syncsynp = stats.pearsonr(csv_input['Speaker1_syntactic_self_distance'], csv_input['Speaker2_syntactic_self_distance'])
    csv_input['Syncrony-Pearson rho_syntactic'] = syncsynr
    csv_input['Syncrony-Pearson p-value_syntactic'] = syncsynp
    #Bonferroni correction
    csv_input['Syncrony-Pearson p-value_syntactic_adj'] = csv_input['Syncrony-Pearson p-value_syntactic'].lt(0.05/12)
    
    syncsemr,syncsemp = stats.pearsonr(csv_input['Speaker1_semantic_self_distance'], csv_input['Speaker2_semantic_self_distance'])
    csv_input['Syncrony-Pearson rho_semantic'] = syncsemr
    csv_input['Syncrony-Pearson p-value_semantic'] = syncsemp
    #Bonferroni correction
    csv_input['Syncrony-Pearson p-value_semantic_adj'] = csv_input['Syncrony-Pearson p-value_semantic'].lt(0.05/12)

    syncaudior,syncaudiop = stats.pearsonr(csv_input['Speaker1_audio_self_distance'], csv_input['Speaker2_audio_self_distance'])
    csv_input['Syncrony-Pearson rho_audio'] = syncaudior
    csv_input['Syncrony-Pearson p-value_audio'] = syncaudiop
    #Bonferroni correction
    csv_input['Syncrony-Pearson p-value_audio_adj'] = csv_input['Syncrony-Pearson p-value_audio'].lt(0.05/12)
 

    csv_input.drop(['Same_pair_lexical', 'Not_Same_Pair_lexical', 'Same_pair_syntactic', 'Not_Same_Pair_syntactic',
                    'Same_pair_semantic', 'Not_Same_Pair_semantic', 'Same_pair_audio', 'Not_Same_Pair_audio',
                    'Speaker1_lexical_self_distance','Speaker2_lexical_self_distance','Turn_number','Speaker1_syntactic_self_distance',
                    'Speaker2_syntactic_self_distance','Speaker1_semantic_self_distance','Speaker2_semantic_self_distance',
                    'Speaker1_audio_self_distance','Speaker2_audio_self_distance'], axis=1,inplace=True)
    csv_input = csv_input.loc[[0]]
    csv_input.to_csv(out_name, index=False,sep='\t')
    del csv_input,proximity_lexical,proximity_syntactic,proximity_semantic,proximity_audio,
    convlexr,convlexp,convsynr,convsynp,convsemr,convsemp,convaudior,convaudiop,
    synclexr,synclexp,syncsynr,syncsynp,syncsemr,syncsemp,syncaudior,syncaudiop

# %%
#Step Nine 
## Program to merge output files generated at Eight step
# The program concatenates statistical output of each inidividual sessions into one file
import pandas as pd
import glob

#Specify Input path for files generated in previous step
list_of_files = glob.glob(r'D:\Jay\columbia-games-corpus\statsoutput\*.txt',recursive=True)
#Specify Output path
out_name = r'D:\Jay\columbia-games-corpus\output\combined_output'
li = []

for filename in list_of_files:
    df = pd.read_csv(filename, index_col=None, header=0, delimiter='\t')
    basename = os.path.basename(filename)
    file_name = os.path.splitext(basename)[0]
    df['File_name'] = file_name
    #Re-arrange columns with filename as first column
    cols = df.columns.tolist()
    cols = cols[-1:] + cols[:-1]
    #Define new arranged column to data-frame
    df = df[cols]
    #Append the dataframe to list
    li.append(df)
frame = pd.concat(li, axis=0, ignore_index=True) 

frame.to_csv(out_name+'.csv', index=False,sep=',')

# %%
#Final Step 
## Program to find correlation between adjacent turns at lexical, syntactic, semantic and acoustic linguistic levels
## Find correlation using pearson correlation
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
file_name=r'D:\Jay\columbia-games-corpus\output\combined_output.csv'

df=pd.read_csv(file_name,delimiter=',')
df.rename(columns = {'Same_pair_lexical':'Lexical','Same_pair_syntactic':'Syntactic', 
                     'Same_pair_semantic':'Semantic', 'Same_pair_audio':'Acoustic'}, inplace = True)
group1=df[['Lexical','Syntactic','Semantic','Acoustic']]

corr = group1.corr()
corr
plt.rcParams.update({'font.size': 18})
ax.tick_params(axis='both', which='major', labelsize=14)
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(corr,cmap='coolwarm', vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = np.arange(0,len(group1.columns),1)
ax.set_xticks(ticks)
plt.xticks(rotation=90)
ax.set_yticks(ticks)
ax.set_xticklabels(group1.columns)
ax.set_yticklabels(group1.columns)
for (i, j), z in np.ndenumerate(corr):
    ax.text(j, i, '{:0.2f}'.format(z), ha='center', va='center')
plt.show()
